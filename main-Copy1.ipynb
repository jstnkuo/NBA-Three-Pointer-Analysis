# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# NBA data files
league_pergame_path = "Resources/League_PerGame_Year.csv"
team_records_path = "Resources/Team_Records_Per_Year.csv"
nba_team_stats_records_path = "Resources/nba_team_stats&records.csv"
nbapointratios_path = "Resources/nbapointratios.csv"
league_pergame = pd.read_csv(league_pergame_path)
team_records = pd.read_csv(team_records_path)
nba_team_stats_records = pd.read_csv(nba_team_stats_records_path)
nbapointratios = pd.read_csv(nbapointratios_path)
league_pergame_clean = league_pergame.set_index(['Season'])
league_pergame_cleaner = league_pergame_clean.drop(columns = 'Rk')
league_pergame_cleaner.head()
# Out:
#           Lg   Age     Ht     Wt     G     MP    FG   FGA    3P   3PA  ...  \
# Season                                                                 ...
# 2022-23  NBA  26.2  6-Jun  216.0   705  241.9  41.6  88.2  12.3  34.2  ...
# 2021-22  NBA  26.1  6-Jun  215.0  1230  241.4  40.6  88.1  12.4  35.2  ...
# 2020-21  NBA  26.1  6-Jun  217.0  1080  241.4  41.2  88.4  12.7  34.6  ...
# 2019-20  NBA  26.1  6-Jun  218.0  1059  241.8  40.9  88.8  12.2  34.1  ...
# 2018-19  NBA  26.3  6-Jun  219.0  1230  241.6  41.1  89.2  11.4  32.0  ...
#
#            PTS    FG%    3P%    FT%   Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# Season
# 2022-23  114.1  0.472  0.359  0.781   99.3  0.542  12.8  24.2   0.211  114.1
# 2021-22  110.6  0.461  0.354  0.775   98.2  0.532  12.3  23.2   0.192  112.0
# 2020-21  112.1  0.466  0.367  0.778   99.2  0.538  12.4  22.2   0.192  112.3
# 2019-20  111.8  0.460  0.358  0.773  100.3  0.529  12.8  22.5   0.201  110.6
# 2018-19  111.2  0.461  0.355  0.766  100.0  0.524  12.4  22.9   0.198  110.4
#
# [5 rows x 30 columns]

# %% [markdown]
# #Three Point Attempt over Time

# %%
three_point_percent = league_pergame_cleaner['3P%']
three_point_percent.head()
three_point_percent.plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
team_records.head()
# Out:
#     Season   Lg             Team   W   L   W/L%  Finish   SRS  Pace  Rel_Pace  \
# 0  2017-18  NBA   Boston Celtics  29  10  0.744       1  4.38  95.4      -1.7
# 1  2016-17  NBA  Boston Celtics*  53  29  0.646       1  2.25  96.8       0.4
# 2  2015-16  NBA  Boston Celtics*  48  34  0.585       2  2.84  98.5       2.7
# 3  2014-15  NBA  Boston Celtics*  40  42  0.488       2 -0.40  95.8       1.9
# 4  2013-14  NBA   Boston Celtics  25  57  0.305       4 -4.97  93.3      -0.6
#
#     ORtg  Rel_ORtg   DRtg  Rel_DRtg                Playoffs  \
# 0  108.0       0.2  102.8      -5.0                     NaN
# 1  111.2       2.4  108.4      -0.4    Lost E. Conf. Finals
# 2  106.8       0.4  103.6      -2.8  Lost E. Conf. 1st Rnd.
# 3  104.7      -0.9  104.5      -1.1  Lost E. Conf. 1st Rnd.
# 4  102.9      -3.8  107.7       1.0                     NaN
#
#               Coaches            Top WS
# 0  B. Stevens (29-10)   K. Irving (5.7)
# 1  B. Stevens (53-29)  I. Thomas (12.5)
# 2  B. Stevens (48-34)   I. Thomas (9.7)
# 3  B. Stevens (40-42)   T. Zeller (6.5)
# 4  B. Stevens (25-57)     B. Bass (5.1)

# %%
nba_team_stats_records
# Out:
#          Year  PF_Rank               Team                  Year&Team     G  \
# 0     2022-23     10.0      Atlanta Hawks      2022-23_Atlanta Hawks  47.0
# 1     2022-23      2.0     Boston Celtics     2022-23_Boston Celtics  47.0
# 2     2022-23     16.0      Brooklyn Nets      2022-23_Brooklyn Nets  46.0
# 3     2022-23     21.0  Charlotte Hornets  2022-23_Charlotte Hornets  47.0
# 4     2022-23     13.0      Chicago Bulls      2022-23_Chicago Bulls  45.0
# ...       ...      ...                ...                        ...   ...
# 1478      NaN      NaN                NaN                        NaN   NaN
# 1479      NaN      NaN                NaN                        NaN   NaN
# 1480      NaN      NaN                NaN                        NaN   NaN
# 1481      NaN      NaN                NaN                        NaN   NaN
# 1482      NaN      NaN                NaN                        NaN   NaN
#
#          MP    FG   FGA    FG%    3P  ...   AST  STL  BLK   TOV    PF    PTS  \
# 0     242.7  43.8  92.0  0.476  10.6  ...  24.2  7.0  5.0  12.9  19.3  116.0
# 1     242.7  42.1  88.7  0.475  15.5  ...  26.7  6.5  5.4  13.4  18.7  118.5
# 2     240.5  42.7  84.0  0.508  12.1  ...  26.3  7.1  7.0  14.6  21.9  113.7
# 3     243.2  42.0  92.7  0.453  11.1  ...  25.4  7.9  4.9  13.6  21.1  112.6
# 4     242.8  42.8  87.5  0.489  10.8  ...  24.4  7.6  4.7  13.7  19.7  114.8
# ...     ...   ...   ...    ...   ...  ...   ...  ...  ...   ...   ...    ...
# 1478    NaN   NaN   NaN    NaN   NaN  ...   NaN  NaN  NaN   NaN   NaN    NaN
# 1479    NaN   NaN   NaN    NaN   NaN  ...   NaN  NaN  NaN   NaN   NaN    NaN
# 1480    NaN   NaN   NaN    NaN   NaN  ...   NaN  NaN  NaN   NaN   NaN    NaN
# 1481    NaN   NaN   NaN    NaN   NaN  ...   NaN  NaN  NaN   NaN   NaN    NaN
# 1482    NaN   NaN   NaN    NaN   NaN  ...   NaN  NaN  NaN   NaN   NaN    NaN
#
#          W     L   W/L%  Playoffs
# 0     24.0  23.0  0.511       NaN
# 1     35.0  12.0  0.745       NaN
# 2     29.0  17.0  0.630       NaN
# 3     13.0  34.0  0.277       NaN
# 4     21.0  24.0  0.467       NaN
# ...    ...   ...    ...       ...
# 1478   NaN   NaN    NaN       NaN
# 1479   NaN   NaN    NaN       NaN
# 1480   NaN   NaN    NaN       NaN
# 1481   NaN   NaN    NaN       NaN
# 1482   NaN   NaN    NaN       NaN
#
# [1483 rows x 31 columns]

# %%
nba_team_stats_records.head()
# nba_team_stats_records.dropna(how = 'any', inplace = True)
# nba_team_stats_records[['Playoffs', '3P%']]
won_finals = nba_team_stats_records[nba_team_stats_records['Playoffs'] == 'Won Finals']
three_point_percent_winners = won_finals['3P%']
year_winners = won_finals['Year']

plt.plot(year_winners, three_point_percent_winners)
plt.xticks(rotation = 90)
plt.show()

# %%
won_finals
# Out:
#         Year  PF_Rank                    Team                       Year&Team  \
# 39   2021-22     15.0  Golden State Warriors*  2021-22_Golden State Warriors*
# 76   2020-21      1.0        Milwaukee Bucks*        2020-21_Milwaukee Bucks*
# 103  2019-20     11.0     Los Angeles Lakers*     2019-20_Los Angeles Lakers*
# 147  2018-19      8.0        Toronto Raptors*        2018-19_Toronto Raptors*
# 159  2017-18      1.0  Golden State Warriors*  2017-18_Golden State Warriors*
# 189  2016-17      1.0  Golden State Warriors*  2016-17_Golden State Warriors*
# 215  2015-16      8.0    Cleveland Cavaliers*    2015-16_Cleveland Cavaliers*
# 249  2014-15      1.0  Golden State Warriors*  2014-15_Golden State Warriors*
# 296  2013-14      6.0      San Antonio Spurs*      2013-14_San Antonio Spurs*
# 315  2012-13      5.0             Miami Heat*             2012-13_Miami Heat*
# 344  2011-12      7.0             Miami Heat*               40878_Miami Heat*
# 365  2010-11     11.0       Dallas Mavericks*         40483_Dallas Mavericks*
# 402  2009-10     12.0     Los Angeles Lakers*       40087_Los Angeles Lakers*
# 432  2008-09      3.0     Los Angeles Lakers*       39692_Los Angeles Lakers*
# 460  2007-08     11.0         Boston Celtics*           39295_Boston Celtics*
# 493  2006-07     14.0      San Antonio Spurs*        38899_San Antonio Spurs*
# 524  2005-06      6.0             Miami Heat*               38504_Miami Heat*
# 565  2004-05     18.0      San Antonio Spurs*        38108_San Antonio Spurs*
# 576  2003-04     24.0        Detroit Pistons*          37712_Detroit Pistons*
# 623  2002-03     12.0      San Antonio Spurs*        37316_San Antonio Spurs*
# 640  2001-02      3.0     Los Angeles Lakers*       36923_Los Angeles Lakers*
# 669  2000-01      3.0     Los Angeles Lakers*       36526_Los Angeles Lakers*
#
#         G     MP    FG   FGA    FG%    3P  ...   AST  STL  BLK   TOV    PF  \
# 39   82.0  240.6  40.5  86.4  0.469  14.3  ...  27.1  8.8  4.5  14.9  21.0
# 76   72.0  240.7  44.7  91.8  0.487  14.4  ...  25.5  8.1  4.6  13.8  17.3
# 103  71.0  240.7  42.3  88.3  0.480  11.0  ...  25.4  8.6  6.6  15.2  20.7
# 147  82.0  242.4  42.2  89.1  0.474  12.4  ...  25.4  8.3  5.3  14.0  21.0
# 159  82.0  240.6  42.8  85.1  0.503  11.3  ...  29.3  8.0  7.5  15.5  19.6
# 189  82.0  241.2  43.1  87.1  0.495  12.0  ...  30.4  9.6  6.8  14.8  19.3
# 215  82.0  242.1  38.7  84.0  0.460  10.7  ...  22.7  6.7  3.9  13.6  20.3
# 249  82.0  240.6  41.6  87.0  0.478  10.8  ...  27.4  9.3  6.0  14.5  19.9
# 296  82.0  240.9  40.6  83.5  0.486   8.5  ...  25.2  7.4  5.1  14.4  18.2
# 315  82.0  242.4  38.4  77.4  0.496   8.7  ...  23.0  8.7  5.4  13.9  18.7
# 344  66.0  243.0  37.1  79.0  0.469   5.6  ...  20.0  8.9  5.4  15.2  19.4
# 365  82.0  240.3  37.4  78.8  0.475   7.9  ...  23.8  6.8  4.3  14.0  19.2
# 402  82.0  241.8  38.3  83.8  0.457   6.5  ...  21.1  7.5  4.9  13.4  19.4
# 432  82.0  241.2  40.3  85.1  0.474   6.7  ...  23.3  8.8  5.1  13.5  20.7
# 460  82.0  240.9  36.4  76.7  0.475   7.3  ...  22.4  8.5  4.6  15.2  22.7
# 493  82.0  241.2  36.6  77.2  0.474   7.3  ...  22.1  7.2  5.1  13.9  19.4
# 524  82.0  240.9  37.1  77.5  0.478   6.1  ...  20.6  6.4  5.4  14.5  22.8
# 565  82.0  241.5  35.6  78.7  0.453   6.2  ...  21.6  7.5  6.6  13.7  20.9
# 576  82.0  241.2  33.5  77.0  0.435   4.1  ...  20.8  8.0  7.0  15.1  20.3
# 623  82.0  241.8  35.5  76.8  0.462   5.5  ...  20.0  7.7  6.5  15.8  20.4
# 640  82.0  241.2  38.4  83.4  0.461   6.2  ...  23.0  7.6  5.8  12.7  22.2
# 669  82.0  242.7  37.9  81.5  0.465   5.4  ...  23.0  6.9  6.0  14.4  22.8
#
#        PTS     W     L   W/L%    Playoffs
# 39   111.0  53.0  29.0  0.646  Won Finals
# 76   120.1  46.0  26.0  0.639  Won Finals
# 103  113.4  52.0  19.0  0.732  Won Finals
# 147  114.4  58.0  24.0  0.707  Won Finals
# 159  113.5  28.0   8.0  0.778  Won Finals
# 189  115.9  67.0  15.0  0.817  Won Finals
# 215  104.3  57.0  25.0  0.695  Won Finals
# 249  110.0  67.0  15.0  0.817  Won Finals
# 296  105.4  62.0  20.0  0.756  Won Finals
# 315  102.9  66.0  16.0  0.805  Won Finals
# 344   98.5  46.0  20.0  0.697  Won Finals
# 365  100.2  57.0  25.0  0.695  Won Finals
# 402  101.7  57.0  25.0  0.695  Won Finals
# 432  106.9  65.0  17.0  0.793  Won Finals
# 460  100.5  66.0  16.0  0.805  Won Finals
# 493   98.5  58.0  24.0  0.707  Won Finals
# 524   99.9  52.0  30.0  0.634  Won Finals
# 565   96.2  59.0  23.0  0.720  Won Finals
# 576   90.1  54.0  28.0  0.659  Won Finals
# 623   95.8  60.0  22.0  0.732  Won Finals
# 640  101.3  58.0  24.0  0.707  Won Finals
# 669  100.6  56.0  26.0  0.683  Won Finals
#
# [22 rows x 31 columns]

# %%
nba_team_stats_records["Playoffs"] = nba_team_stats_records["Playoffs"].fillna(0)
nba_team_stats_records = nba_team_stats_records.dropna()

# %%
nba_team_stats_records
# Out:
#         Year  PF_Rank                 Team                  Year&Team     G  \
# 0    2022-23     10.0        Atlanta Hawks      2022-23_Atlanta Hawks  47.0
# 1    2022-23      2.0       Boston Celtics     2022-23_Boston Celtics  47.0
# 2    2022-23     16.0        Brooklyn Nets      2022-23_Brooklyn Nets  46.0
# 3    2022-23     21.0    Charlotte Hornets  2022-23_Charlotte Hornets  47.0
# 4    2022-23     13.0        Chicago Bulls      2022-23_Chicago Bulls  45.0
# ..       ...      ...                  ...                        ...   ...
# 681  2000-01      7.0  Seattle SuperSonics  36526_Seattle SuperSonics  82.0
# 682  2000-01      5.0     Toronto Raptors*     36526_Toronto Raptors*  82.0
# 683  2000-01     10.0           Utah Jazz*           36526_Utah Jazz*  82.0
# 684  2000-01     25.0  Vancouver Grizzlies  36526_Vancouver Grizzlies  82.0
# 685  2000-01     18.0   Washington Wizards   36526_Washington Wizards  82.0
#
#         MP    FG   FGA    FG%    3P  ...   AST  STL  BLK   TOV    PF    PTS  \
# 0    242.7  43.8  92.0  0.476  10.6  ...  24.2  7.0  5.0  12.9  19.3  116.0
# 1    242.7  42.1  88.7  0.475  15.5  ...  26.7  6.5  5.4  13.4  18.7  118.5
# 2    240.5  42.7  84.0  0.508  12.1  ...  26.3  7.1  7.0  14.6  21.9  113.7
# 3    243.2  42.0  92.7  0.453  11.1  ...  25.4  7.9  4.9  13.6  21.1  112.6
# 4    242.8  42.8  87.5  0.489  10.8  ...  24.4  7.6  4.7  13.7  19.7  114.8
# ..     ...   ...   ...    ...   ...  ...   ...  ...  ...   ...   ...    ...
# 681  241.5  36.9  81.1  0.456   5.7  ...  21.9  8.0  5.0  15.3  21.1   97.3
# 682  243.4  37.2  85.0  0.437   5.2  ...  24.4  7.3  6.3  13.2  21.3   97.6
# 683  241.2  36.1  76.7  0.471   4.0  ...  25.7  8.1  5.6  15.8  25.7   97.1
# 684  241.2  35.0  79.7  0.439   4.0  ...  23.2  7.1  4.4  15.7  21.1   91.7
# 685  240.0  34.5  78.7  0.439   3.4  ...  20.1  7.7  4.7  17.0  23.3   93.2
#
#         W     L   W/L%                Playoffs
# 0    24.0  23.0  0.511                       0
# 1    35.0  12.0  0.745                       0
# 2    29.0  17.0  0.630                       0
# 3    13.0  34.0  0.277                       0
# 4    21.0  24.0  0.467                       0
# ..    ...   ...    ...                     ...
# 681  44.0  38.0  0.537                       0
# 682  47.0  35.0  0.573     Lost E. Conf. Semis
# 683  53.0  29.0  0.646  Lost W. Conf. 1st Rnd.
# 684  23.0  59.0  0.280                       0
# 685  19.0  63.0  0.232                       0
#
# [686 rows x 31 columns]

# %%
# clean off datas that are incomplete
lose_finals = nba_team_stats_records.loc[nba_team_stats_records["Year"]!= "2022-23"]
lose_finals = lose_finals.loc[lose_finals["Playoffs"] != "Won Finals"]
lose_finals
# Out:
#         Year  PF_Rank                 Team                  Year&Team     G  \
# 30   2021-22      6.0       Atlanta Hawks*     2021-22_Atlanta Hawks*  82.0
# 31   2021-22     12.0      Boston Celtics*    2021-22_Boston Celtics*  82.0
# 32   2021-22      9.0       Brooklyn Nets*     2021-22_Brooklyn Nets*  82.0
# 33   2021-22      4.0    Charlotte Hornets  2021-22_Charlotte Hornets  82.0
# 34   2021-22     13.0       Chicago Bulls*     2021-22_Chicago Bulls*  82.0
# ..       ...      ...                  ...                        ...   ...
# 681  2000-01      7.0  Seattle SuperSonics  36526_Seattle SuperSonics  82.0
# 682  2000-01      5.0     Toronto Raptors*     36526_Toronto Raptors*  82.0
# 683  2000-01     10.0           Utah Jazz*           36526_Utah Jazz*  82.0
# 684  2000-01     25.0  Vancouver Grizzlies  36526_Vancouver Grizzlies  82.0
# 685  2000-01     18.0   Washington Wizards   36526_Washington Wizards  82.0
#
#         MP    FG   FGA    FG%    3P  ...   AST  STL  BLK   TOV    PF    PTS  \
# 30   240.3  41.5  88.3  0.470  12.9  ...  24.6  7.2  4.2  11.9  18.7  113.9
# 31   242.7  40.7  87.4  0.466  13.2  ...  24.8  7.2  5.8  13.6  18.5  111.8
# 32   240.9  42.0  88.4  0.475  11.5  ...  25.3  7.1  5.5  14.1  20.4  112.9
# 33   242.4  42.8  91.4  0.468  13.9  ...  28.1  8.6  4.9  13.3  19.9  115.3
# 34   240.6  41.7  86.9  0.480  10.6  ...  23.9  7.1  4.1  12.8  18.8  111.6
# ..     ...   ...   ...    ...   ...  ...   ...  ...  ...   ...   ...    ...
# 681  241.5  36.9  81.1  0.456   5.7  ...  21.9  8.0  5.0  15.3  21.1   97.3
# 682  243.4  37.2  85.0  0.437   5.2  ...  24.4  7.3  6.3  13.2  21.3   97.6
# 683  241.2  36.1  76.7  0.471   4.0  ...  25.7  8.1  5.6  15.8  25.7   97.1
# 684  241.2  35.0  79.7  0.439   4.0  ...  23.2  7.1  4.4  15.7  21.1   91.7
# 685  240.0  34.5  78.7  0.439   3.4  ...  20.1  7.7  4.7  17.0  23.3   93.2
#
#         W     L   W/L%                Playoffs
# 30   43.0  39.0  0.524                       0
# 31   51.0  31.0  0.622                       0
# 32   44.0  38.0  0.537                       0
# 33   43.0  39.0  0.524                       0
# 34   46.0  36.0  0.561                       0
# ..    ...   ...    ...                     ...
# 681  44.0  38.0  0.537                       0
# 682  47.0  35.0  0.573     Lost E. Conf. Semis
# 683  53.0  29.0  0.646  Lost W. Conf. 1st Rnd.
# 684  23.0  59.0  0.280                       0
# 685  19.0  63.0  0.232                       0
#
# [634 rows x 31 columns]

# %%
# using loop to checkout how much row of datas each year have
count = 1
count_list = []
year_list = []
year = ""
p3 = 0
for i in lose_finals['Year']:
    if i != year :
        year = i
        count_list.append(count)
        count = 1
        year_list.append(year)
    else :
        count += 1
    
  
print(count_list)
# Out:
# [1, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 28, 28]

# %%
count_2021 = len(lose_finals.loc[lose_finals['Year']== "2021-22"])
count_list[0] = count_2021
print(count_list)
# Out:
# [29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 28, 28]

# %%
lose_finals['3P%'].head()
# Out:
# 30    0.374
# 31    0.356
# 32    0.361
# 33    0.365
# 34    0.369
# Name: 3P%, dtype: float64

# %%
# Using loop to to list the average 3P% of losers

#a = lose_finals["3P%"][0: 29].mean()
                  # i  i + 29 -1 + 1
#b = lose_finals["3P%"][29: 58].mean()
#lose_finals["3P%"][60: 89]
# # Using loop for calculate each year losers 3 point percentage (2000-1 to 2021-22)
avg_list = []
count = 0
for i in count_list:
                            #   0      0+29 = 29, count = 29
                            #   29     29+29
                            #   58     58+29
    avg_3 = lose_finals["3P%"][count : count+i].mean()
    avg_list.append(avg_3)
    count += i 
print(avg_list)
# Out:
# [0.3532068965517241, 0.3652413793103448, 0.35806896551724143, 0.35513793103448266, 0.3607241379310345, 0.3562758620689655, 0.35244827586206895, 0.3474137931034483, 0.35744827586206895, 0.3562413793103448, 0.34682758620689663, 0.3559655172413794, 0.3531724137931035, 0.36558620689655175, 0.3595172413793104, 0.3559655172413793, 0.3572758620689655, 0.3528275862068965, 0.3457931034482758, 0.3464285714285714, 0.35178571428571426, 0.351925925925926]

# %%
lost_finals_year_avg = pd.DataFrame({"Year":year_list, "3P%": avg_list})
lost_finals_year_avg.head()
# Out:
#       Year       3P%
# 0  2021-22  0.353207
# 1  2020-21  0.365241
# 2  2019-20  0.358069
# 3  2018-19  0.355138
# 4  2017-18  0.360724

# %%
# making multipule lines plot to compare 
plt.plot(year_list, avg_list,marker = 'o', label="loser" )
plt.plot(year_list, three_point_percent_winners,marker = 'o', label="winner" )
plt.xticks(rotation = 90)
plt.legend(loc="best")
plt.xlabel("Year")
plt.ylabel("3P%")
plt.title("Compare 3P% by Year")
plt.show()

# %%
# loser Boxplot
plt.boxplot(lost_finals_year_avg['3P%'], showfliers=True)
plt.title("Loser 3P%")
plt.show()
quartiles = lost_finals_year_avg['3P%'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of 3P% is: {lowerq}")
print(f"The upper quartile of 3P% is: {upperq}")
print(f"The interquartile range of 3P% is: {iqr}")
print(f"The the median of 3P% is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound, 2)} could be outliers.")
print(f"Values above {round(upper_bound, 2)} could be outliers.")
# Out:
# The lower quartile of 3P% is: 0.3520565134099617
# The upper quartile of 3P% is: 0.3574051724137931
# The interquartile range of 3P% is: 0.005348659003831413
# The the median of 3P% is: 0.355551724137931
# Values below 0.34 could be outliers.
# Values above 0.37 could be outliers.

# %%
# Winner Boxplot
plt.boxplot(three_point_percent_winners, showfliers = True)
plt.title("Winner 3P%")
plt.show()
quartiles = three_point_percent_winners.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of 3P% is: {lowerq}")
print(f"The upper quartile of 3P% is: {upperq}")
print(f"The interquartile range of 3P% is: {iqr}")
print(f"The the median of 3P% is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {round(lower_bound, 2)} could be outliers.")
print(f"Values above {round(upper_bound, 2)} could be outliers.")
# Out:
# The lower quartile of 3P% is: 0.354
# The upper quartile of 3P% is: 0.3825
# The interquartile range of 3P% is: 0.028500000000000025
# The the median of 3P% is: 0.3635
# Values below 0.31 could be outliers.
# Values above 0.43 could be outliers.

# %%
nbapointratios.head()
# Out:
#     Season  3PPoints    FT  2PPoints    PTS
# 0  2022-23      36.9  18.6      58.6  114.1
# 1  2021-22      37.2  16.9      56.5  110.6
# 2  2020-21      38.1  17.0      57.0  112.1
# 3  2019-20      36.6  17.9      57.3  111.8
# 4  2018-19      34.2  17.7      59.3  111.2

# %%
nbapointratios.head(10)
# Out:
#     Season  3PPoints    FT  2PPoints    PTS
# 0  2022-23      36.9  18.6      58.6  114.1
# 1  2021-22      37.2  16.9      56.5  110.6
# 2  2020-21      38.1  17.0      57.0  112.1
# 3  2019-20      36.6  17.9      57.3  111.8
# 4  2018-19      34.2  17.7      59.3  111.2
# 5  2017-18      31.5  16.6      58.2  106.3
# 6  2016-17      29.1  17.8      58.7  105.6
# 7  2015-16      25.5  17.7      59.5  102.7
# 8  2014-15      23.4  17.1      59.5  100.0
# 9  2013-14      23.1  17.8      60.1  101.0

# %%
nbapointratios["3P%"] = nbapointratios['3PPoints'] / nbapointratios['PTS']
nbapointratios["Others%"] = 1 - nbapointratios["3P%"]
nbapointratios
# Out:
#      Season  3PPoints    FT  2PPoints    PTS       3P%   Others%
# 0   2022-23      36.9  18.6      58.6  114.1  0.323401  0.676599
# 1   2021-22      37.2  16.9      56.5  110.6  0.336347  0.663653
# 2   2020-21      38.1  17.0      57.0  112.1  0.339875  0.660125
# 3   2019-20      36.6  17.9      57.3  111.8  0.327370  0.672630
# 4   2018-19      34.2  17.7      59.3  111.2  0.307554  0.692446
# ..      ...       ...   ...       ...    ...       ...       ...
# 72  1950-51       0.0  24.5      59.6   84.1  0.000000  1.000000
# 73  1949-50       0.0  23.6      56.4   80.0  0.000000  1.000000
# 74  1948-49       0.0  22.0      58.0   80.0  0.000000  1.000000
# 75  1947-48       0.0  18.2      54.5   72.7  0.000000  1.000000
# 76  1946-47       0.0  15.9      51.9   67.8  0.000000  1.000000
#
# [77 rows x 7 columns]

# %%
# generate a list of 3p% average by each decade
nbapointratios.head(30)
nbapointratios_20s = nbapointratios.iloc[0:3,]
nbapointratios_20s
p3_20 = round(nbapointratios_20s['3P%'].mean(), 2)
p_other_20 = round(nbapointratios_20s["Others%"].mean(), 2)
count = 1
p3 = 0
p_other = 0
p3_list = [p3_20]
p_other_list = [p_other_20]
for i in range(3, 43) :
    if count != 10 :
        p3 += nbapointratios["3P%"][i]
        p_other += nbapointratios["Others%"][i]
        count += 1
    else:
        
        p3 += nbapointratios["3P%"][i]
        p_other += nbapointratios["Others%"][i]
        p3_list.append(round(p3/10, 2))
        p_other_list.append(round(p_other/10, 2))
        
        
        count = 1
        p3 = 0
        p_other = 0

# %%
labels = ["20's", "10's", "00's", "90's", "80's"]

width = 0.35
fig, ax = plt.subplots()

ax.bar(labels, p3_list, width, label='3Points',bottom=p_other_list,)
ax.bar(labels, p_other_list, width, 
       label='Others')

ax.set_ylabel('Scores percentage')
ax.set_title('Scores Percentage by 3Point and Others Each Decade')
ax.legend(loc="best")
f = plt.figure(figsize = (16, 15))
plt.show()
